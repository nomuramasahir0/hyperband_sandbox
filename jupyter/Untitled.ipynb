# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid')

# %%
plt.figure()
for i in range(46):
    df = pd.read_csv("../log_{}.csv".format(i))
#     plt.plot(df['1'], color=cm.hsv((float(i) * 2) /92.0))
    plt.plot(df['1'])
plt.xlabel("epoch")
plt.ylim(1.0, 10.0)
# plt.grid()
plt.ylabel("validation error rate")
plt.title("hyperband with mnist")
plt.savefig("hb_result.pdf")
